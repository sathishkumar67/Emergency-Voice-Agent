# %%
import pandas as pd

db = pd.read_csv("bangalore_sop.csv")
db.head()
# Out:
#            Incident Type                                         Department  \
# 0          Building Fire       Bangalore Fire and Emergency Services (BFES)
# 1          Building Fire          Bruhat Bengaluru Mahanagara Palike (BBMP)
# 2          Building Fire           Bangalore Police (Bengaluru City Police)
# 3          Building Fire  Karnataka State Disaster Management Authority ...
# 4  Road Traffic Accident                           Bangalore Traffic Police
#
#                                            SOP Steps
# 0  1. Receive alert via 101 or Integrated Command...
# 1  1. Receive incident notification from ICCC or ...
# 2  1. Receive alert from PCR (100) or ICCC. 2. Di...
# 3  1. Activate State Emergency Operations Centre ...
# 4  1. Receive PCR call (103) or ICCC alert. 2. Di...
