# %%
import sqlite3
import pandas as pd

# Connect
conn = sqlite3.connect('emergency_data.db')

# Read SQL into DataFrame
df = pd.read_sql_query("SELECT * FROM incidents", conn)

# Display
print(df)

# Close
conn.close()
# Out:
# Empty DataFrame
# Columns: [id, ticket_id, timestamp, caller_name, location, incident_type, classification, confidence, priority, sentiment, description, language, json_file_path]
# Index: []
